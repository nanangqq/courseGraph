# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.stats as stats

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 5435-401B
#
#  C:\Users\yooky\courseGraph 디렉터리
#
# 2019-10-07  오전 11:15    <DIR>          .
# 2019-10-07  오전 11:15    <DIR>          ..
# 2019-10-07  오전 11:15    <DIR>          .ipynb_checkpoints
# 2019-10-02  오후 04:19    <DIR>          .vscode
# 2019-10-07  오전 11:01    <DIR>          data
# 2019-10-04  오후 05:50            13,720 graphMerge.CSV
# 2019-10-02  오후 04:58             9,398 graphMerge.py
# 2019-10-02  오후 04:29             7,605 graphMerge_.CSV
# 2019-10-06  오후 09:58            23,956 graphMerge_1006.CSV
# 2019-10-07  오전 10:15               316 map.py
# 2019-10-06  오후 10:13            66,056 merged.json
# 2019-10-04  오전 09:32            21,193 merged_1004.json
# 2019-10-07  오전 11:15                72 Untitled.ipynb
#                8개 파일             142,316 바이트
#                5개 디렉터리  107,228,467,200 바이트 남음

# %%
import json
from pprint import pprint
with open('merged.json', 'r', encoding='utf8') as f:
    data = json.load(f)
pprint(data)
# Out:
# {'cps': [[150, 90],
#          [450, 90],
#          [750, 90],
#          [1050, 90],
#          [1350, 90],
#          [1650, 90],
#          [1950, 90],
#          [2250, 90],
#          [2550, 90],
#          [2850, 90],
#          [3150, 90],
#          [3450, 90],
#          [3750, 90],
#          [150, 270],
#          [450, 270],
#          [750, 270],
#          [1050, 270],
#          [1350, 270],
#          [1650, 270],
#          [1950, 270],
#          [2250, 270],
#          [2550, 270],
#          [2850, 270],
#          [3150, 270],
#          [3450, 270],
#          [3750, 270],
#          [150, 450],
#          [450, 450],
#          [750, 450],
#          [1050, 450],
#          [1350, 450],
#          [1650, 450],
#          [1950, 450],
#          [2250, 450],
#          [2550, 450],
#          [2850, 450],
#          [3150, 450],
#          [3450, 450],
#          [3750, 450],
#          [150, 630],
#          [450, 630],
#          [750, 630],
#          [1050, 630],
#          [1350, 630],
#          [1650, 630],
#          [1950, 630],
#          [2250, 630],
#          [2550, 630],
#          [2850, 630],
#          [3150, 630],
#          [3450, 630],
#          [3750, 630],
#          [150, 810],
#          [450, 810],
#          [750, 810],
#          [1050, 810],
#          [1350, 810],
#          [1650, 810],
#          [1950, 810],
#          [2250, 810],
#          [2550, 810],
#          [2850, 810],
#          [3150, 810],
#          [3450, 810],
#          [3750, 810],
#          [150, 990],
#          [450, 990],
#          [750, 990],
#          [1050, 990],
#          [1350, 990],
#          [1650, 990],
#          [1950, 990],
#          [2250, 990],
#          [2550, 990],
#          [2850, 990],
#          [3150, 990],
#          [3450, 990],
#          [3750, 990],
#          [150, 1170],
#          [450, 1170],
#          [750, 1170],
#          [1050, 1170],
#          [1350, 1170],
#          [1650, 1170],
#          [1950, 1170],
#          [2250, 1170],
#          [2550, 1170],
#          [2850, 1170],
#          [3150, 1170],
#          [3450, 1170],
#          [3750, 1170],
#          [150, 1350],
#          [450, 1350],
#          [750, 1350],
#          [1050, 1350],
#          [1350, 1350],
#          [1650, 1350],
#          [1950, 1350],
#          [2250, 1350],
#          [2550, 1350],
#          [2850, 1350],
#          [3150, 1350],
#          [3450, 1350],
#          [3750, 1350],
#          [150, 1530],
#          [450, 1530],
#          [750, 1530],
#          [1050, 1530],
#          [1350, 1530],
#          [1650, 1530],
#          [1950, 1530],
#          [2250, 1530],
#          [2550, 1530],
#          [2850, 1530],
#          [3150, 1530],
#          [3450, 1530],
#          [3750, 1530],
#          [150, 1710],
#          [450, 1710],
#          [750, 1710],
#          [1050, 1710],
#          [1350, 1710],
#          [1650, 1710],
#          [1950, 1710],
#          [2250, 1710],
#          [2550, 1710],
#          [2850, 1710],
#          [3150, 1710],
#          [3450, 1710],
#          [3750, 1710],
#          [150, 1890],
#          [450, 1890],
#          [750, 1890],
#          [1050, 1890],
#          [1350, 1890],
#          [1650, 1890],
#          [1950, 1890],
#          [2250, 1890],
#          [2550, 1890],
#          [2850, 1890],
#          [3150, 1890],
#          [3450, 1890],
#          [3750, 1890],
#          [150, 2070],
#          [450, 2070],
#          [750, 2070],
#          [1050, 2070],
#          [1350, 2070],
#          [1650, 2070],
#          [1950, 2070],
#          [2250, 2070],
#          [2550, 2070],
#          [2850, 2070],
#          [3150, 2070],
#          [3450, 2070],
#          [3750, 2070],
#          [150, 2250],
#          [450, 2250],
#          [750, 2250],
#          [1050, 2250],
#          [1350, 2250],
#          [1650, 2250],
#          [1950, 2250],
#          [2250, 2250],
#          [2550, 2250],
#          [2850, 2250],
#          [3150, 2250],
#          [3450, 2250],
#          [3750, 2250],
#          [150, 2430],
#          [450, 2430],
#          [750, 2430],
#          [1050, 2430],
#          [1350, 2430],
#          [1650, 2430],
#          [1950, 2430],
#          [2250, 2430],
#          [2550, 2430],
#          [2850, 2430],
#          [3150, 2430],
#          [3450, 2430],
#          [3750, 2430],
#          [150, 2610],
#          [450, 2610],
#          [750, 2610],
#          [1050, 2610],
#          [1350, 2610],
#          [1650, 2610],
#          [1950, 2610],
#          [2250, 2610],
#          [2550, 2610],
#          [2850, 2610],
#          [3150, 2610],
#          [3450, 2610],
#          [3750, 2610]],
#  'crsList': [{'key': '1',
#               'props': {'cp': [450, 90],
#                         'crs_id': 'test1',
#                         'name': 'Introduction to Computer Programming',
#                         'prerequisites': {'test56': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 21.3,
#                         'source': {'Berkeley': [[1,
#                                                  'The Structure and '
#                                                  'Interpretation of Computer '
#                                                  'Programs']],
#                                    'CMU': [[1,
#                                             'Principles of Imperative '
#                                             'Computation']],
#                                    'GeorgiaTech': [[1,
#                                                     'Introduction to '
#                                                     'Computing']],
#                                    'KAIST': [[1, '전산응용개론'], [1, '프로그래밍기초']],
#                                    'Korea': [],
#                                    'MIT': [[1,
#                                             'Introduction to Computer Science '
#                                             'Programming in Python']],
#                                    'SNU': [[1, '컴퓨터 프로그래밍']],
#                                    'Udemy': [[1, 'Python(파이썬) 프로그래밍 제대로 배우기']],
#                                    'udacity': [[1,
#                                                 'Introduction to Python '
#                                                 'Programming']]},
#                         'sourceWeight': 9}},
#              {'key': '2',
#               'props': {'cp': [750, 90],
#                         'crs_id': 'test2',
#                         'name': 'Introduction to Computer Programming for '
#                                 'Everyone',
#                         'prerequisites': {'test24': 1, 'test67': 1},
#                         'prqWeightIn': 2,
#                         'prqWeightOut': 22.099999999999998,
#                         'source': {'Berkeley': [[1,
#                                                  'Introduction to Computer '
#                                                  'Programming for Scientists '
#                                                  'and Engineers']],
#                                    'CMU': [[1, 'Computing @ Carnegie Mellon']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[1, '프로그래밍 실습']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '컴퓨터의 개념 및 실습']],
#                                    'Udemy': [[1, 'Python(파이썬) 프로그래밍 제대로 배우기'],
#                                              [0.5,
#                                               'Python for Data Science and '
#                                               'Machine Learning Bootcamp'],
#                                              [1,
#                                               'Fundamentals of Java with '
#                                               'NetBeans'],
#                                              [1,
#                                               'The Ultimate Python Programming '
#                                               'Tutorial'],
#                                              [1,
#                                               'Python for beginners & logic '
#                                               'building practice Questions '
#                                               '3.7'],
#                                              [1,
#                                               'JavaScript Basics for '
#                                               'Beginners']],
#                                    'udacity': [[1,
#                                                 'Introduction to Python '
#                                                 'Programming']]},
#                         'sourceWeight': 10.5}},
#              {'key': '3',
#               'props': {'cp': [1050, 90],
#                         'crs_id': 'test3',
#                         'name': 'Object Oriented Programming',
#                         'prerequisites': {'test1': 1.7, 'test3': 1},
#                         'prqWeightIn': 2.7,
#                         'prqWeightOut': 8.0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Introduction to Object '
#                                                     'Oriented Programming'],
#                                                    [1, 'Objects and Design']],
#                                    'KAIST': [[0.5, '프로그래밍의 이해']],
#                                    'Korea': [],
#                                    'MIT': [[0.7,
#                                             'Fundamentals of Programming']],
#                                    'SNU': [[0.5, '컴퓨터 프로그래밍']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 3.7}},
#              {'key': '7',
#               'props': {'cp': [2250, 90],
#                         'crs_id': 'test4',
#                         'name': 'Data Structures',
#                         'prerequisites': {'test2': 1,
#                                           'test26': 0.8,
#                                           'test3': 0.5,
#                                           'test43': 1,
#                                           'test55': 0.3},
#                         'prqWeightIn': 3.6,
#                         'prqWeightOut': 15.200000000000001,
#                         'source': {'Berkeley': [[1, 'Data Structures']],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Data Structures and '
#                                                     'Algorithms for '
#                                                     'Applications']],
#                                    'KAIST': [[1, '데이타구조']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '자료구조']],
#                                    'Udemy': [[1,
#                                               'Python(파이썬) 응용_자료구조 제대로 배우기']],
#                                    'udacity': []},
#                         'sourceWeight': 5}},
#              {'key': '8',
#               'props': {'cp': [2550, 90],
#                         'crs_id': 'test5',
#                         'name': '프로그래밍의 원리',
#                         'prerequisites': {'test3': 0.5},
#                         'prqWeightIn': 0.5,
#                         'prqWeightOut': 1,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[0.7, '프로그래밍의 이해']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '프로그래밍의 원리']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1.7}},
#              {'key': '9',
#               'props': {'cp': [2850, 90],
#                         'crs_id': 'test6',
#                         'name': '프로그래밍 언어',
#                         'prerequisites': {'test3': 1, 'test4': 1, 'test5': 1},
#                         'prqWeightIn': 3,
#                         'prqWeightOut': 1,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Languages and '
#                                                     'Computation']],
#                                    'KAIST': [[1, '프로그래밍 언어'],
#                                              [1, '프로그래밍 언어 이론']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '프로그래밍 언어']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 4}},
#              {'key': '10',
#               'props': {'cp': [3150, 90],
#                         'crs_id': 'test7',
#                         'name': '컴파일러',
#                         'prerequisites': {'test11': 1, 'test13': 1, 'test6': 1},
#                         'prqWeightIn': 3,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '컴파일러']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '11',
#               'props': {'cp': [3450, 90],
#                         'crs_id': 'test8',
#                         'name': 'Algorithms',
#                         'prerequisites': {'test1': 1.7,
#                                           'test26': 2.7,
#                                           'test27': 0.9,
#                                           'test3': 1.2,
#                                           'test4': 2.9,
#                                           'test55': 0.7,
#                                           'test8': 0.5},
#                         'prqWeightIn': 10.600000000000001,
#                         'prqWeightOut': 9.54,
#                         'source': {'Berkeley': [[0.9,
#                                                  'Efficient Algorithms and '
#                                                  'Intractable Problems']],
#                                    'CMU': [[0.7,
#                                             'Parallel and Sequential Data '
#                                             'Structures and Algorithms']],
#                                    'GeorgiaTech': [[0.5,
#                                                     'Data Structures and '
#                                                     'Algorithms for '
#                                                     'Applications'],
#                                                    [1,
#                                                     'Design and Analysis of '
#                                                     'Algorithms']],
#                                    'KAIST': [[1, '알고리즘 개론']],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Introduction to Algorithms']],
#                                    'SNU': [[1, '알고리즘']],
#                                    'Udemy': [[0.7, '지능적인 파이썬 검색 알고리즘']],
#                                    'udacity': []},
#                         'sourceWeight': 6.800000000000001}},
#              {'key': '86',
#               'props': {'cp': [2550, 1170],
#                         'crs_id': 'test9',
#                         'name': 'Graduate Algorithms',
#                         'prerequisites': {'test15': 0.9,
#                                           'test26': 0.5,
#                                           'test8': 2.5,
#                                           'test9': 6},
#                         'prqWeightIn': 9.9,
#                         'prqWeightOut': 8.4,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1, 'Graduate Algorithms'],
#                                            [1, 'Algorithms in the Real World']],
#                                    'GeorgiaTech': [[1,
#                                                     'Computability, '
#                                                     'Algorithms, and '
#                                                     'Complexity'],
#                                                    [1,
#                                                     'Introduction to Graduate '
#                                                     'Algorithms'],
#                                                    [1,
#                                                     'Design and Analysis of '
#                                                     'Algorithms(graduate)'],
#                                                    [1, 'Graph Algorithms'],
#                                                    [1,
#                                                     'Approximation Algorithms'],
#                                                    [1, 'Randomized Algorithms'],
#                                                    [1,
#                                                     'Markov Chain Monte Carlo '
#                                                     'Algorithms'],
#                                                    [1,
#                                                     'Spectral Algorithms and '
#                                                     'Representations'],
#                                                    [1,
#                                                     ' Computational Science '
#                                                     'and Engineering '
#                                                     'Algorithms']],
#                                    'KAIST': [[0.7, '분산 알고리즘 및 시스템'],
#                                              [1, '알고리즘 설계와 해석']],
#                                    'Korea': [],
#                                    'MIT': [[1,
#                                             'Design and Analysis of '
#                                             'Algorithms'],
#                                            [1, 'Algorithms for Inference']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 14.7}},
#              {'key': '12',
#               'props': {'cp': [3750, 90],
#                         'crs_id': 'test10',
#                         'name': 'Computational Complexity Theory',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Computational Complexity '
#                                                     'Theory']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '15',
#               'props': {'cp': [750, 270],
#                         'crs_id': 'test11',
#                         'name': 'Computer Systems',
#                         'prerequisites': {'test1': 1,
#                                           'test11': 0.25,
#                                           'test15': 2,
#                                           'test24': 0.5,
#                                           'test3': 0.7,
#                                           'test55': 0.15},
#                         'prqWeightIn': 4.6,
#                         'prqWeightOut': 5.75,
#                         'source': {'Berkeley': [[0.5,
#                                                  'Designing Information '
#                                                  'Devices and Systems 1'],
#                                                 [0.5,
#                                                  'Designing Information '
#                                                  'Devices and Systems 2']],
#                                    'CMU': [[1,
#                                             'Introduction to Computer '
#                                             'Systems']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[1, '시스템 프로그래밍'],
#                                              [0.8, '소프트웨어 및 시스템 설계']],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Computer Systems Engineering']],
#                                    'SNU': [[1, '시스템 프로그래밍']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 5.8}},
#              {'key': '16',
#               'props': {'cp': [1050, 270],
#                         'crs_id': 'test12',
#                         'name': 'Database',
#                         'prerequisites': {'test4': 2},
#                         'prqWeightIn': 2,
#                         'prqWeightOut': 0.35,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[0.5,
#                                             'Multimedia Databases and '
#                                             'Datamining']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[1, '데이타베이스 개론'],
#                                              [1, '데이타베이스 시스템'],
#                                              [1, '데이터베이스 설계']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '데이터베이스']],
#                                    'Udemy': [[0.5,
#                                               'SQL BootCamp 2019 - SQL for '
#                                               'Beginners (SQL Mastery '
#                                               'Course)']],
#                                    'udacity': []},
#                         'sourceWeight': 5.0}},
#              {'key': '17',
#               'props': {'cp': [1350, 270],
#                         'crs_id': 'test13',
#                         'name': '오토마타',
#                         'prerequisites': {'test26': 2.1, 'test8': 1},
#                         'prqWeightIn': 3.1,
#                         'prqWeightOut': 1,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Automata and Complexity '
#                                                     'Theory']],
#                                    'KAIST': [[1, '형식언어 및 오토마타']],
#                                    'Korea': [],
#                                    'MIT': [[1,
#                                             'Automata, Computability, and '
#                                             'Complexity']],
#                                    'SNU': [[1, '오토마타 이론']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 4}},
#              {'key': '19',
#               'props': {'cp': [1950, 270],
#                         'crs_id': 'test14',
#                         'name': '논리설계',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 1,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '논리설계']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '20',
#               'props': {'cp': [2250, 270],
#                         'crs_id': 'test15',
#                         'name': '컴퓨터 구조',
#                         'prerequisites': {'test1': 1,
#                                           'test14': 1,
#                                           'test17': 0.7,
#                                           'test3': 0.9},
#                         'prqWeightIn': 3.6,
#                         'prqWeightOut': 5.800000000000001,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[0.9,
#                                                     'Computer Organization and '
#                                                     'Programming']],
#                                    'KAIST': [[0.7, '전산기조직'], [1, '컴퓨터 구조']],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Computation Structures']],
#                                    'SNU': [[1, '컴퓨터 구조']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 4.6}},
#              {'key': '21',
#               'props': {'cp': [2550, 270],
#                         'crs_id': 'test16',
#                         'name': '운영체제',
#                         'prerequisites': {'test11': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 2,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[1, '운영체제 및 실험'], [1, '운영체제']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '운영체제']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 3}},
#              {'key': '23',
#               'props': {'cp': [3150, 270],
#                         'crs_id': 'test17',
#                         'name': '전기전자회로',
#                         'prerequisites': {'test24': 2},
#                         'prqWeightIn': 2,
#                         'prqWeightOut': 2.5,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[0.5,
#                                                     'Prototyping Intelligence '
#                                                     'Appliances']],
#                                    'KAIST': [[1, '디지탈시스템 및 실험']],
#                                    'Korea': [],
#                                    'MIT': [[0.5,
#                                             'Introduction to EECS via '
#                                             'Robotics']],
#                                    'SNU': [[1, '전기전자회로']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 3.0}},
#              {'key': '24',
#               'props': {'cp': [3450, 270],
#                         'crs_id': 'test18',
#                         'name': '하드웨어시스템설계',
#                         'prerequisites': {'test1': 0.5,
#                                           'test15': 1,
#                                           'test17': 1.8},
#                         'prqWeightIn': 3.3,
#                         'prqWeightOut': 1.0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[0.8, '내장형 컴퓨터 시스템']],
#                                    'Korea': [],
#                                    'MIT': [[0.5,
#                                             'Introduction to EECS via '
#                                             'Robotics']],
#                                    'SNU': [[1, '하드웨어시스템설계']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 2.3}},
#              {'key': '94',
#               'props': {'cp': [1050, 1350],
#                         'crs_id': 'test19',
#                         'name': 'Great Ideas in Theoretical Computer Science',
#                         'prerequisites': {'test1': 1, 'test55': 1, 'test56': 1},
#                         'prqWeightIn': 3,
#                         'prqWeightOut': 2,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1,
#                                             'Great Ideas in Theoretical '
#                                             'Computer Science']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '25',
#               'props': {'cp': [3750, 270],
#                         'crs_id': 'test20',
#                         'name': 'Software Design',
#                         'prerequisites': {'test1': 0.7, 'test3': 1.2},
#                         'prqWeightIn': 1.9,
#                         'prqWeightOut': 1,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[0.7,
#                                             'Designing Human Centered '
#                                             'Software:']],
#                                    'GeorgiaTech': [[1,
#                                                     'Software Development '
#                                                     'Process']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1,
#                                             'Elements of Software '
#                                             'Construction']],
#                                    'SNU': [[1, '소프트웨어 개발의 원리와 실습']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 3.7}},
#              {'key': '28',
#               'props': {'cp': [750, 450],
#                         'crs_id': 'test21',
#                         'name': 'Software Engineering',
#                         'prerequisites': {'test20': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Advanced Topics in '
#                                                     'Software Engineering']],
#                                    'KAIST': [[1, '소프트웨어 공학개론'],
#                                              [1, '소프트웨어 공학'],
#                                              [1, '소프트웨어 시스템 모델링']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [[1, '소프트웨어 공학']],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 5}},
#              {'key': '29',
#               'props': {'cp': [1050, 450],
#                         'crs_id': 'test22',
#                         'name': 'Human-Computer Interaction',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Human-Computer '
#                                                     'Interaction']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '30',
#               'props': {'cp': [1350, 450],
#                         'crs_id': 'test23',
#                         'name': '기초수학',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 14.2,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [[1, 'Become an Algebra Master'],
#                                              [1,
#                                               'Become a Trigonometry & '
#                                               'Precalculus Master'],
#                                              [1, 'Become a Geometry Master']],
#                                    'udacity': []},
#                         'sourceWeight': 3}},
#              {'key': '31',
#               'props': {'cp': [1650, 450],
#                         'crs_id': 'test24',
#                         'name': 'Calculus',
#                         'prerequisites': {'test24': 2},
#                         'prqWeightIn': 2,
#                         'prqWeightOut': 22.4,
#                         'source': {'Berkeley': [[1, 'Calculus'],
#                                                 [1, 'Multivariable Calculus']],
#                                    'CMU': [[1,
#                                             'Differential and Integral '
#                                             'Calculus']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [[1, '미적분 (Calculus)']],
#                                    'MIT': [],
#                                    'SNU': [[1, '공학수학 1'], [1, '공학수학 2']],
#                                    'Udemy': [[1, 'Become a Calculus 1 Master'],
#                                              [1,
#                                               'Calculus I - Introduction to '
#                                               'Derivatives']],
#                                    'udacity': []},
#                         'sourceWeight': 8}},
#              {'key': '32',
#               'props': {'cp': [1950, 450],
#                         'crs_id': 'test25',
#                         'name': 'Linear Algebra',
#                         'prerequisites': {'test23': 0.7, 'test24': 2.6},
#                         'prqWeightIn': 3.3,
#                         'prqWeightOut': 17.240000000000002,
#                         'source': {'Berkeley': [[1,
#                                                  'Linear Algebra and '
#                                                  'Differential Equations']],
#                                    'CMU': [[0.8,
#                                             'Matrices and Linear '
#                                             'Transformations']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [[1, '선형대수 (Linear Algebra)']],
#                                    'MIT': [],
#                                    'SNU': [[0.8, '선형 및 비선형 계산모델']],
#                                    'Udemy': [[0.7, 'Matrix Algebra'],
#                                              [1,
#                                               'Become a Linear Algebra '
#                                               'Master']],
#                                    'udacity': [[1,
#                                                 'Linear Algebra Refresher '
#                                                 'Course']]},
#                         'sourceWeight': 6.3}},
#              {'key': '33',
#               'props': {'cp': [2250, 450],
#                         'crs_id': 'test26',
#                         'name': 'Discrete Mathematics and Probability Theory',
#                         'prerequisites': {'test51': 0.8},
#                         'prqWeightIn': 0.8,
#                         'prqWeightOut': 17.400000000000002,
#                         'source': {'Berkeley': [[1,
#                                                  'Discrete Mathematics and '
#                                                  'Probability Theory']],
#                                    'CMU': [[0.8,
#                                             'Probability Theory for Computer '
#                                             'Scientists']],
#                                    'GeorgiaTech': [[0.5,
#                                                     'Introduction to Discrete '
#                                                     'Mathematics for Computer '
#                                                     'Science']],
#                                    'KAIST': [[0.8, '이산구조']],
#                                    'Korea': [[0.8,
#                                               '확률과 통계 (Probability and '
#                                               'Statistics)']],
#                                    'MIT': [[0.5, 'Introduction to Probability'],
#                                            [0.5,
#                                             'Mathematics for Computer '
#                                             'Science']],
#                                    'SNU': [[0.8, '이산수학']],
#                                    'Udemy': [[0.7,
#                                               'Become a Probability & '
#                                               'Statistics Master']],
#                                    'udacity': []},
#                         'sourceWeight': 6.4}},
#              {'key': '85',
#               'props': {'cp': [2250, 1170],
#                         'crs_id': 'test27',
#                         'name': 'Probability and Computing',
#                         'prerequisites': {'test19': 1,
#                                           'test25': 0.8,
#                                           'test26': 1},
#                         'prqWeightIn': 2.8,
#                         'prqWeightOut': 1.9,
#                         'source': {'Berkeley': [[1,
#                                                  'Probability and Random '
#                                                  'Processes']],
#                                    'CMU': [[1, 'Probability and Computing']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [[1, '확률적 프로그래밍']],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 3}},
#              {'key': '126',
#               'props': {'cp': [2850, 1710],
#                         'crs_id': 'test28',
#                         'name': 'Advanced Methods for Data Analysis',
#                         'prerequisites': {'test31': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1,
#                                             'Advanced Methods for Data '
#                                             'Analysis']],
#                                    'GeorgiaTech': [[0.5,
#                                                     'Big Data Systems and '
#                                                     'Analytics']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1.5}},
#              {'key': '34',
#               'props': {'cp': [2550, 450],
#                         'crs_id': 'test29',
#                         'name': 'Introduction to Statistics',
#                         'prerequisites': {'test29': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 12.69,
#                         'source': {'Berkeley': [[1,
#                                                  'Introduction to Statistics']],
#                                    'CMU': [[1,
#                                             'Probability and Mathematical '
#                                             'Statistics']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [[0.8,
#                                               '확률과 통계 (Probability and '
#                                               'Statistics)']],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [[0.7,
#                                               'Become a Probability & '
#                                               'Statistics Master']],
#                                    'udacity': [[1,
#                                                 'Intro to Inferential '
#                                                 'Statistics'],
#                                                [1,
#                                                 'Intro to Descriptive '
#                                                 'Statistics']]},
#                         'sourceWeight': 5.5}},
#              {'key': '174',
#               'props': {'cp': [1650, 2430],
#                         'crs_id': 'test30',
#                         'name': 'Intermediate Statistics',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 2,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1, 'Intermediate Statistics']],
#                                    'GeorgiaTech': [[0.5,
#                                                     ' Computational '
#                                                     'Statistics']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1.5}},
#              {'key': '113',
#               'props': {'cp': [2850, 1530],
#                         'crs_id': 'test31',
#                         'name': 'Modern Regression',
#                         'prerequisites': {'test25': 0.8, 'test26': 0.8},
#                         'prqWeightIn': 1.6,
#                         'prqWeightOut': 1,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1, 'Modern Regression']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '190',
#               'props': {'cp': [2550, 2610],
#                         'crs_id': 'test32',
#                         'name': 'Regression Analysis',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1, 'Regression Analysis']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '187',
#               'props': {'cp': [1650, 2610],
#                         'crs_id': 'test33',
#                         'name': 'Advanced Statistical Theory I',
#                         'prerequisites': {'test30': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1,
#                                             'Advanced Statistical Theory I']],
#                                    'GeorgiaTech': [[0.5, ' Bayesian Methods']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1.5}},
#              {'key': '186',
#               'props': {'cp': [1350, 2610],
#                         'crs_id': 'test34',
#                         'name': 'Advanced Statistical Theory:',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [[1, 'Advanced Statistical Theory:']],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '36',
#               'props': {'cp': [3150, 450],
#                         'crs_id': 'test35',
#                         'name': 'Inference and Information',
#                         'prerequisites': {'test26': 0.5},
#                         'prqWeightIn': 0.5,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Introduction to '
#                                                     'Information Theory']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Inference and Information']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 2}},
#              {'key': '38',
#               'props': {'cp': [3750, 450],
#                         'crs_id': 'test36',
#                         'name': 'Topics in Machine Learning',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
# ...
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 3,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Principles of Microeconomics']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '70',
#               'props': {'cp': [1650, 990],
#                         'crs_id': 'test101',
#                         'name': 'Intermediate Macroeconomics',
#                         'prerequisites': {'test100': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Intermediate Macroeconomics']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '71',
#               'props': {'cp': [1950, 990],
#                         'crs_id': 'test102',
#                         'name': 'Economic Applications of Game Theory',
#                         'prerequisites': {'test100': 1, 'test26': 0.5},
#                         'prqWeightIn': 1.5,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1,
#                                             'Economic Applications of Game '
#                                             'Theory']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '72',
#               'props': {'cp': [2250, 990],
#                         'crs_id': 'test103',
#                         'name': 'Psychology and Economics',
#                         'prerequisites': {'test100': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Psychology and Economics']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '73',
#               'props': {'cp': [2550, 990],
#                         'crs_id': 'test104',
#                         'name': 'Econometric Data Science',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1, 'Econometric Data Science']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '74',
#               'props': {'cp': [2850, 990],
#                         'crs_id': 'test105',
#                         'name': 'Stochastic Models in Business Analytics',
#                         'prerequisites': {'test26': 0.5},
#                         'prqWeightIn': 0.5,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [[1,
#                                             'Stochastic Models in Business '
#                                             'Analytics']],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 1}},
#              {'key': '75',
#               'props': {'cp': [3150, 990],
#                         'crs_id': 'test106',
#                         'name': 'Artificial Intelligence for Business',
#                         'prerequisites': {'test106': 4,
#                                           'test2': 2,
#                                           'test23': 3,
#                                           'test24': 1,
#                                           'test4': 2,
#                                           'test43': 1.0,
#                                           'test57': 1},
#                         'prqWeightIn': 14.0,
#                         'prqWeightOut': 5,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [[1,
#                                               'Artificial Intelligence for '
#                                               'Business'],
#                                              [1,
#                                               'Artificial Intelligence & '
#                                               'Machine Learning for Business'],
#                                              [1,
#                                               'Power Your Business with '
#                                               'Artificial Intelligence'],
#                                              [1,
#                                               'Artificial Intelligence: '
#                                               'Practical Essentials for '
#                                               'Management'],
#                                              [1,
#                                               'Introduction to AI for '
#                                               'Business'],
#                                              [1,
#                                               'Hands-On Artificial '
#                                               'Intelligence for Small '
#                                               'Businesses'],
#                                              [1,
#                                               '인공 지능(AI/ML) 활용 비즈니스 모델 수립 강좌 - '
#                                               '기초편 -']],
#                                    'udacity': []},
#                         'sourceWeight': 7}},
#              {'key': '76',
#               'props': {'cp': [3450, 990],
#                         'crs_id': 'test107',
#                         'name': 'Machine Learning for Trading',
#                         'prerequisites': {'test107': 4,
#                                           'test2': 1,
#                                           'test25': 2,
#                                           'test29': 1.7,
#                                           'test44': 2,
#                                           'test67': 1},
#                         'prqWeightIn': 11.7,
#                         'prqWeightOut': 5,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Machine Learning for '
#                                                     'Trading'],
#                                                    [1,
#                                                     'Machine Learning for '
#                                                     'Trading(graduate)']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [[1,
#                                               'Predict the stock market with '
#                                               'data and model building!'],
#                                              [1, '인공 지능을 갖춘 투자자 로봇-모듈 1'],
#                                              [1, '인공 지능을 갖춘 투자자 로봇-모듈 2'],
#                                              [1, 'Trader를 위한 인공지능의 기초'],
#                                              [1,
#                                               'Python for Financial Analysis '
#                                               'and Algorithmic Trading']],
#                                    'udacity': [[1,
#                                                 'Artificial Intelligence for '
#                                                 'Trading'],
#                                                [1,
#                                                 'Machine Learning for '
#                                                 'Trading']]},
#                         'sourceWeight': 9}},
#              {'key': '80',
#               'props': {'cp': [750, 1170],
#                         'crs_id': 'test108',
#                         'name': 'Computational Social Science',
#                         'prerequisites': {},
#                         'prqWeightIn': 0,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [[1,
#                                                     'Computational Journalism'],
#                                                    [1,
#                                                     'Computational '
#                                                     'Journalism(graduate)'],
#                                                    [1,
#                                                     'Computational Social '
#                                                     'Science']],
#                                    'KAIST': [],
#                                    'Korea': [],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [],
#                                    'udacity': []},
#                         'sourceWeight': 3}},
#              {'key': '81',
#               'props': {'cp': [1050, 1170],
#                         'crs_id': 'test109',
#                         'name': 'IT 창업/사업 관련',
#                         'prerequisites': {'test57': 1},
#                         'prqWeightIn': 1,
#                         'prqWeightOut': 0,
#                         'source': {'Berkeley': [],
#                                    'CMU': [],
#                                    'GeorgiaTech': [],
#                                    'KAIST': [],
#                                    'Korea': [[0,
#                                               'IT 창업 및 경영 (IT Founding and '
#                                               'Business)'],
#                                              [0,
#                                               '창의혁신론 (Creative Innovation '
#                                               'Theory)'],
#                                              [0,
#                                               '지적재산권법 (Intellectual Property '
#                                               'Right)'],
#                                              [0,
#                                               '기술사업화 (Technology '
#                                               'Commercialization)'],
#                                              [0,
#                                               '기술 마케팅 (Technology Marketing)'],
#                                              [0,
#                                               '창업 보육 정책/법규 (Incubator Policy '
#                                               'and Regulation)']],
#                                    'MIT': [],
#                                    'SNU': [],
#                                    'Udemy': [[1,
#                                               '인공지능(AI/ML)사업추진인력에 필요한 '
#                                               '기술/육성방법']],
#                                    'udacity': []},
#                         'sourceWeight': 1}}],
#  'map': {'0': 'test77',
#          '1': 'test1',
#          '10': 'test7',
#          '103': 'test96',
#          '11': 'test8',
#          '112': 'test78',
#          '113': 'test31',
#          '114': 'test83',
#          '12': 'test10',
#          '121': 'test65',
#          '126': 'test28',
#          '13': 'test99',
#          '131': 'test90',
#          '134': 'test97',
#          '135': 'test52',
#          '136': 'test38',
#          '139': 'test44',
#          '14': 'test76',
#          '15': 'test11',
#          '152': 'test40',
#          '157': 'test98',
#          '159': 'test41',
#          '16': 'test12',
#          '160': 'test42',
#          '161': 'test59',
#          '165': 'test72',
#          '17': 'test13',
#          '170': 'test86',
#          '174': 'test30',
#          '175': 'test39',
#          '177': 'test61',
#          '178': 'test69',
#          '179': 'test68',
#          '18': 'test56',
#          '186': 'test34',
#          '187': 'test33',
#          '189': 'test67',
#          '19': 'test14',
#          '190': 'test32',
#          '191': 'test50',
#          '192': 'test85',
#          '2': 'test2',
#          '20': 'test15',
#          '21': 'test16',
#          '23': 'test17',
#          '24': 'test18',
#          '25': 'test20',
#          '26': 'test54',
#          '27': 'test53',
#          '28': 'test21',
#          '29': 'test22',
#          '3': 'test3',
#          '30': 'test23',
#          '31': 'test24',
#          '32': 'test25',
#          '33': 'test26',
#          '34': 'test29',
#          '36': 'test35',
#          '37': 'test75',
#          '38': 'test36',
#          '39': 'test43',
#          '40': 'test45',
#          '41': 'test46',
#          '42': 'test47',
#          '43': 'test48',
#          '44': 'test49',
#          '46': 'test57',
#          '47': 'test58',
#          '48': 'test60',
#          '49': 'test62',
#          '51': 'test63',
#          '52': 'test84',
#          '54': 'test64',
#          '55': 'test66',
#          '56': 'test70',
#          '57': 'test71',
#          '58': 'test73',
#          '59': 'test74',
#          '60': 'test79',
#          '61': 'test80',
#          '62': 'test87',
#          '63': 'test88',
#          '64': 'test89',
#          '65': 'test91',
#          '66': 'test93',
#          '67': 'test55',
#          '68': 'test94',
#          '69': 'test100',
#          '7': 'test4',
#          '70': 'test101',
#          '71': 'test102',
#          '72': 'test103',
#          '73': 'test104',
#          '74': 'test105',
#          '75': 'test106',
#          '76': 'test107',
#          '77': 'test92',
#          '78': 'test81',
#          '8': 'test5',
#          '80': 'test108',
#          '81': 'test109',
#          '85': 'test27',
#          '86': 'test9',
#          '89': 'test51',
#          '9': 'test6',
#          '90': 'test95',
#          '92': 'test82',
#          '94': 'test19',
#          '97': 'test37'},
#  'merged': True,
#  'view_size': [3900, 2700]}

# %%
swList=[]
for crs in data['crsList']:
#     print(crs['props']['name'], crs['props']['sourceWeight'])
    swList.append(crs['props']['sourceWeight'])

# %%
swList=pd.Series(swList)
swList.hist()

# %%
swList.plot.box()

# %%
swList.describe()
# Out:
# count    109.000000
# mean       3.888991
# std        3.667206
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       20.300000
# dtype: float64

# %%
prqInList=[]
for crs in data['crsList']:
    prqInList.append(crs['props']['prqWeightIn'])

# %%
prqInList=pd.Series(prqInList)
prqInList.hist()

# %%
prqInList.plot.box()

# %%
prqInList.describe()
# Out:
# count    109.000000
# mean       2.982661
# std        3.936938
# min        0.000000
# 25%        0.500000
# 50%        2.000000
# 75%        3.300000
# max       19.650000
# dtype: float64

# %%
prqOutList=[]
for crs in data['crsList']:
    prqOutList.append(crs['props']['prqWeightOut'])
prqOutList=pd.Series(prqOutList)
prqOutList.hist()

# %%
prqOutList.plot.box()

# %%
prqOutList.describe()
# Out:
# count    109.000000
# mean       2.982661
# std        5.184539
# min        0.000000
# 25%        0.000000
# 50%        0.490000
# 75%        3.500000
# max       22.400000
# dtype: float64

# %%
lwList=[]
for crs in data['crsList']:
    for line in crs['props']['prerequisites'].values():
        lwList.append(line)
lwList=pd.Series(lwList)
lwList.hist()

# %%
lwList.plot.box()

# %%
lwList.describe()
# Out:
# count    275.000000
# mean       1.182218
# std        0.756114
# min        0.150000
# 25%        0.850000
# 50%        1.000000
# 75%        1.000000
# max        6.000000
# dtype: float64
