# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.stats as stats

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 5435-401B
#
#  C:\Users\yooky\courseGraph 디렉터리
#
# 2019-10-07  오전 11:15    <DIR>          .
# 2019-10-07  오전 11:15    <DIR>          ..
# 2019-10-07  오전 11:15    <DIR>          .ipynb_checkpoints
# 2019-10-02  오후 04:19    <DIR>          .vscode
# 2019-10-07  오전 11:01    <DIR>          data
# 2019-10-04  오후 05:50            13,720 graphMerge.CSV
# 2019-10-02  오후 04:58             9,398 graphMerge.py
# 2019-10-02  오후 04:29             7,605 graphMerge_.CSV
# 2019-10-06  오후 09:58            23,956 graphMerge_1006.CSV
# 2019-10-07  오전 10:15               316 map.py
# 2019-10-06  오후 10:13            66,056 merged.json
# 2019-10-04  오전 09:32            21,193 merged_1004.json
# 2019-10-07  오전 11:15                72 Untitled.ipynb
#                8개 파일             142,316 바이트
#                5개 디렉터리  107,228,467,200 바이트 남음

# %%
import json
with open('merged.json', 'r', encoding='utf8') as f:
    data = json.load(f)
print(data)
# Out:
# {'crsList': [{'key': '1', 'props': {'crs_id': 'test1', 'name': 'Introduction to Computer Programming', 'source': {'SNU': [[1, '컴퓨터 프로그래밍']], 'KAIST': [[1, '전산응용개론'], [1, '프로그래밍기초']], 'Korea': [], 'udacity': [[1, 'Introduction to Python Programming']], 'Udemy': [[1, 'Python(파이썬) 프로그래밍 제대로 배우기']], 'CMU': [[1, 'Principles of Imperative Computation']], 'Berkeley': [[1, 'The Structure and Interpretation of Computer Programs']], 'MIT': [[1, 'Introduction to Computer Science Programming in Python']], 'GeorgiaTech': [[1, 'Introduction to Computing']]}, 'sourceWeight': 9, 'prerequisites': {'test56': 1}, 'prqWeightIn': 1, 'prqWeightOut': 21.3, 'cp': [450, 90]}}, {'key': '2', 'props': {'crs_id': 'test2', 'name': 'Introduction to Computer Programming for Everyone', 'source': {'SNU': [[1, '컴퓨터의 개념 및 실습']], 'KAIST': [[1, '프로그래밍 실습']], 'Korea': [], 'udacity': [[1, 'Introduction to Python Programming']], 'Udemy': [[1, 'Python(파이썬) 프로그래밍 제대로 배우기'], [0.5, 'Python for Data Science and Machine Learning Bootcamp'], [1, 'Fundamentals of Java with NetBeans'], [1, 'The Ultimate Python Programming Tutorial'], [1, 'Python for beginners & logic building practice Questions 3.7'], [1, 'JavaScript Basics for Beginners']], 'CMU': [[1, 'Computing @ Carnegie Mellon']], 'Berkeley': [[1, 'Introduction to Computer Programming for Scientists and Engineers']], 'MIT': [], 'GeorgiaTech': []}, 'sourceWeight': 10.5, 'prerequisites': {'test67': 1, 'test24': 1}, 'prqWeightIn': 2, 'prqWeightOut': 22.099999999999998, 'cp': [750, 90]}}, {'key': '3', 'props': {'crs_id': 'test3', 'name': 'Object Oriented Programming', 'source': {'SNU': [[0.5, '컴퓨터 프로그래밍']], 'KAIST': [[0.5, '프로그래밍의 이해']], 'Korea': [], 'udacity': [], 'Udemy': [], 'CMU': [], 'Berkeley': [], 'MIT': [[0.7, 'Fundamentals of Programming']], 'GeorgiaTech': [[1, 'Introduction to Object Oriented Programming'], [1, 'Objects and Design']]}, 'sourceWeight': 3.7, 'prerequisites': {'test1': 1.7, 'test3': 1}, 'prqWeightIn': 2.7, 'prqWeightOut': 8.0, 'cp': [1050, 90]}}, {'key': '7', 'props': {'crs_id': 'test4', 'name': 'Data Structures', 'source': {'SNU': [[1, '자료구조']], 'KAIST': [[1, '데이타구조']], 'Korea': [], 'udacity': [], 'Udemy': [[1, 'Python(파이썬) 응용_자료구조 제대로 배우기']], 'CMU': [], 'Berkeley': [[1, 'Data Structures']], 'MIT': [], 'GeorgiaTech': [[1, 'Data Structures and Algorithms for Applications']]}, 'sourceWeight': 5, 'prerequisites': {'test3': 0.5, 'test26': 0.8, 'test55': 0.3, 'test43': 1, 'test2': 1}, 'prqWeightIn': 3.6, 'prqWeightOut': 15.200000000000001, 'cp': [2250, 90]}}, {'key': '8', 'props': {'crs_id': 'test5', 'name': '프로그래밍의 원리', 'source': {'SNU': [[1, '프로그래밍의 원리']], 'KAIST': [[0.7, '프로그래밍의 이해']], 'Korea': [], 'udacity': [], 'Udemy': [], 'CMU': [], 'Berkeley': [], 'MIT': [], 'GeorgiaTech': []}, 'sourceWeight': 1.7, 'prerequisites': {'test3': 0.5}, 'prqWeightIn': 0.5, 'prqWeightOut': 1, 'cp': [2550, 90]}}, {'key': '9', 'props': {'crs_id': 'test6', 'name': '프로그래밍 언어', 'source': {'SNU': [[1, '프로그래밍 언어']], 'KAIST': [[1, '프로그래밍 언어'], [1, '프로그래밍 언어 이론']], 'Korea': [], 'udacity': [], 'Udemy': [], 'CMU': [], 'Berkeley': [], 'MIT': [], 'GeorgiaTech': [[1, 'Languages and Computation']]}, 'sourceWeight': 4, 'prerequisites': {'test5': 1, 'test4': 1, 'test3': 1}, 'prqWeightIn': 3, 'prqWeightOut': 1, 'cp': [2850, 90]}}, {'key': '10', 'props': {'crs_id': 'test7', 'name': '컴파일러', 'source': {'SNU': [[1, '컴파일러']], 'KAIST': [], 'Korea': [], 'udacity': [], 'Udemy': [], 'CMU': [], 'Berkeley': [], 'MIT': [], 'GeorgiaTech': []}, 'sourceWeight': 1, 'prerequisites': {'test13': 1, 'test11': 1, 'test6': 1}, 'prqWeightIn': 3, 'prqWeightOut': 0, 'cp': [3150, 90]}}, {'key': '11', 'props': {'crs_id': 'test8', 'name': 'Algorithms', 'source': {'SNU': [[1, '알고리즘']], 'KAIST': [[1, '알고리즘 개론']], 'Korea': [], 'udacity': [], 'Udemy': [[0.7, '지능적인 파이썬 검색 알고리즘']], 'CMU': [[0.7, 'Parallel and Sequential Data Structures and Algorithms']], 'Berkeley': [[0.9, 'Efficient Algorithms and Intractable Problems']], 'MIT': [[1, 'Introduction to Algorithms']], 'Geor ...

# %%
swList=[]
for crs in data['crsList']:
#     print(crs['props']['name'], crs['props']['sourceWeight'])
    swList.append(crs['props']['sourceWeight'])

# %%
swList=pd.Series(swList)
swList.hist()

# %%
swList.plot.box()

# %%
swList.describe()
# Out:
# count    109.000000
# mean       3.888991
# std        3.667206
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       20.300000
# dtype: float64

# %%
prqInList=[]
for crs in data['crsList']:
    prqInList.append(crs['props']['prqWeightIn'])

# %%
prqInList=pd.Series(prqInList)
prqInList.hist()

# %%
prqInList.plot.box()

# %%
prqInList.describe()
# Out:
# count    109.000000
# mean       2.982661
# std        3.936938
# min        0.000000
# 25%        0.500000
# 50%        2.000000
# 75%        3.300000
# max       19.650000
# dtype: float64

# %%
prqOutList=[]
for crs in data['crsList']:
    prqOutList.append(crs['props']['prqWeightOut'])
prqOutList=pd.Series(prqOutList)
prqOutList.hist()

# %%
prqOutList.plot.box()

# %%
prqOutList.describe()
# Out:
# count    109.000000
# mean       2.982661
# std        5.184539
# min        0.000000
# 25%        0.000000
# 50%        0.490000
# 75%        3.500000
# max       22.400000
# dtype: float64

# %%
lwList=[]
for crs in data['crsList']:
    for line in crs['props']['prerequisites'].values():
        lwList.append(line)
lwList=pd.Series(lwList)
lwList.hist()

# %%
lwList.plot.box()

# %%
lwList.describe()
# Out:
# count    275.000000
# mean       1.182218
# std        0.756114
# min        0.150000
# 25%        0.850000
# 50%        1.000000
# 75%        1.000000
# max        6.000000
# dtype: float64
